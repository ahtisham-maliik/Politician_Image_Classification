# %% [markdown]
# # Politician Image Classification

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## (1) Preprocessing: Detect face and eyes
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.
#
# ## Now how do you detect face and eyes?
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_images/imrankhan5.jpg')
img.shape
# Out:
# (256, 197, 3)

# %%
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (256, 197)

# %%
gray
# Out:
# array([[ 34,  34,  34, ...,  35,  35,  35],
#        [ 34,  34,  34, ...,  35,  35,  35],
#        [ 34,  34,  34, ...,  34,  34,  34],
#        ...,
#        [169, 172, 181, ..., 192, 192, 192],
#        [198, 204, 210, ..., 181, 181, 181],
#        [195, 204, 207, ..., 180, 180, 180]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[62, 27, 75, 75]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (62, 27, 75, 75)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)
plt.show()

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# ## (2) Preprocessing: Crop the facial region of the image

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')
plt.show()

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (75, 75, 3)

# %% [markdown]
# ## (3) Preprocessing: Use wavelet transform as a feature for traning our model
# ### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc
# ## Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')
plt.show()

# %% [markdown]
# ### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier
# ## (3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region
# ### Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/imrankhan5.jpg')
plt.imshow(original_image)
plt.show()

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/imrankhan5.jpg')
plt.imshow(cropped_image)
plt.show()

# %% [markdown]
# ### In below image face is not very clear and it doesn't have two eyes clearly visible

# %%
org_image_obstructed = cv2.imread('./test_images/imrankhan6.jpeg')
plt.imshow(org_image_obstructed)
plt.show()

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/imrankhan6.jpeg')
cropped_image_no_2_eyes

# %% [markdown]
# ### Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/asif_ali_zardari',
#  './dataset/general_asim_munir',
#  './dataset/imran_khan',
#  './dataset/nawaz_sharif',
#  './dataset/shahbaz_sharif']

# %% [markdown]
# ### Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = os.path.basename(img_dir)
    celebrity_file_names_dict[celebrity_name] = []

    for entry in os.scandir(img_dir):
        if entry.is_file() and entry.name.lower().endswith(('.png', '.jpg', '.jpeg')):
            print(f"Processing: {entry.path}")
            roi_color = get_cropped_image_if_2_eyes(entry.path)
            if roi_color is not None:
                cropped_folder = os.path.join(path_to_cr_data, celebrity_name)
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    cropped_image_dirs.append(cropped_folder)
                    print("Generating cropped images in folder: ", cropped_folder)

                cropped_file_name = f"{celebrity_name}{count}.png"
                cropped_file_path = os.path.join(cropped_folder, cropped_file_name)
                cv2.imwrite(cropped_file_path, roi_color)
                celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
# Processing: ./dataset/imran_khan\10013.jpeg
# Skipping invalid image: ./dataset/imran_khan\10013.jpeg
# Processing: ./dataset/imran_khan\10014.jpeg
# Skipping invalid image: ./dataset/imran_khan\10014.jpeg
# Processing: ./dataset/imran_khan\10015.jpeg
# Skipping invalid image: ./dataset/imran_khan\10015.jpeg
# Processing: ./dataset/imran_khan\10016.jpeg
# Skipping invalid image: ./dataset/imran_khan\10016.jpeg
# Processing: ./dataset/imran_khan\10018.jpg
# Generating cropped images in folder:  ./dataset/cropped/imran_khan
# Processing: ./dataset/imran_khan\10022.jpg
# Skipping invalid image: ./dataset/imran_khan\10022.jpg
# Processing: ./dataset/imran_khan\10024.jpg
# Skipping invalid image: ./dataset/imran_khan\10024.jpg
# Processing: ./dataset/imran_khan\10026.jpg
# Skipping invalid image: ./dataset/imran_khan\10026.jpg
# Processing: ./dataset/imran_khan\10028.jpg
# Skipping invalid image: ./dataset/imran_khan\10028.jpg
# Processing: ./dataset/imran_khan\10029.jpg
# Skipping invalid image: ./dataset/imran_khan\10029.jpg
# Processing: ./dataset/imran_khan\10030.jpg
# Skipping invalid image: ./dataset/imran_khan\10030.jpg
# Processing: ./dataset/imran_khan\10032.jpg
# Skipping invalid image: ./dataset/imran_khan\10032.jpg
# Processing: ./dataset/imran_khan\10034.jpg
# Skipping invalid image: ./dataset/imran_khan\10034.jpg
# Processing: ./dataset/imran_khan\10039.jpg
# Skipping invalid image: ./dataset/imran_khan\10039.jpg
# Processing: ./dataset/imran_khan\10043.jpg
# Skipping invalid image: ./dataset/imran_khan\10043.jpg
# Processing: ./dataset/imran_khan\10045.jpg
# Skipping invalid image: ./dataset/imran_khan\10045.jpg
# Processing: ./dataset/imran_khan\10048.jpg
# Skipping invalid image: ./dataset/imran_khan\10048.jpg
# Processing: ./dataset/imran_khan\10050.jpg
# Skipping invalid image: ./dataset/imran_khan\10050.jpg
# Processing: ./dataset/imran_khan\10118.jpeg
# Skipping invalid image: ./dataset/imran_khan\10118.jpeg
# Processing: ./dataset/imran_khan\10119.jpeg
# Skipping invalid image: ./dataset/imran_khan\10119.jpeg
# Processing: ./dataset/imran_khan\10120.jpeg
# Skipping invalid image: ./dataset/imran_khan\10120.jpeg
# Processing: ./dataset/imran_khan\10121.jpeg
# Skipping invalid image: ./dataset/imran_khan\10121.jpeg
# Processing: ./dataset/imran_khan\10123.jpeg
# Skipping invalid image: ./dataset/imran_khan\10123.jpeg
# ...
# Skipping invalid image: ./dataset/nawaz_sharif\10289.jpeg
# Processing: ./dataset/nawaz_sharif\10290.jpeg
# Skipping invalid image: ./dataset/nawaz_sharif\10290.jpeg
# Processing: ./dataset/nawaz_sharif\10291.jpg
# Skipping invalid image: ./dataset/nawaz_sharif\10291.jpg
# Processing: ./dataset/nawaz_sharif\10292.jpg
# Processing: ./dataset/nawaz_sharif\10293.jpg
# Processing: ./dataset/nawaz_sharif\10294.jpg
# Processing: ./dataset/nawaz_sharif\10295.jpg
# Processing: ./dataset/nawaz_sharif\10296.jpg
# Processing: ./dataset/nawaz_sharif\10297.jpg
# Skipping invalid image: ./dataset/nawaz_sharif\10297.jpg
# Processing: ./dataset/nawaz_sharif\10299.png
# Processing: ./dataset/nawaz_sharif\10302.jpg
# Skipping invalid image: ./dataset/nawaz_sharif\10302.jpg
# Processing: ./dataset/nawaz_sharif\10304.jpg
# Skipping invalid image: ./dataset/nawaz_sharif\10304.jpg
# Processing: ./dataset/shahbaz_sharif\10006.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10006.jpeg
# Processing: ./dataset/shahbaz_sharif\10007.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10007.jpg
# Processing: ./dataset/shahbaz_sharif\10008.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10008.jpg
# Processing: ./dataset/shahbaz_sharif\10009.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10009.jpg
# Processing: ./dataset/shahbaz_sharif\10012.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10012.jpeg
# Processing: ./dataset/shahbaz_sharif\10014.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10014.jpeg
# Processing: ./dataset/shahbaz_sharif\10015.jpg
# Generating cropped images in folder:  ./dataset/cropped/shahbaz_sharif
# Processing: ./dataset/shahbaz_sharif\10017.jpg
# Processing: ./dataset/shahbaz_sharif\10018.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10018.jpg
# Processing: ./dataset/shahbaz_sharif\10020.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10020.jpg
# Processing: ./dataset/shahbaz_sharif\10021.jpg
# Processing: ./dataset/shahbaz_sharif\10023.jpg
# Processing: ./dataset/shahbaz_sharif\10025.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10025.jpg
# Processing: ./dataset/shahbaz_sharif\10027.jpg
# Processing: ./dataset/shahbaz_sharif\10029.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10029.jpg
# Processing: ./dataset/shahbaz_sharif\10031.jpg
# Processing: ./dataset/shahbaz_sharif\10033.jpg
# Processing: ./dataset/shahbaz_sharif\10034.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10034.jpg
# Processing: ./dataset/shahbaz_sharif\10036.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10036.jpg
# Processing: ./dataset/shahbaz_sharif\10038.jpg
# Processing: ./dataset/shahbaz_sharif\10039.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10039.jpg
# Processing: ./dataset/shahbaz_sharif\10042.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10042.jpg
# Processing: ./dataset/shahbaz_sharif\10043.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10043.jpg
# Processing: ./dataset/shahbaz_sharif\10044.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10044.jpg
# Processing: ./dataset/shahbaz_sharif\10046.jpg
# Processing: ./dataset/shahbaz_sharif\10048.jpg
# Processing: ./dataset/shahbaz_sharif\10049.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10049.jpg
# Processing: ./dataset/shahbaz_sharif\10051.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10051.jpg
# Processing: ./dataset/shahbaz_sharif\10116.jpg
# Processing: ./dataset/shahbaz_sharif\10117.jpg
# Processing: ./dataset/shahbaz_sharif\10118.jpg
# Processing: ./dataset/shahbaz_sharif\10120.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10120.jpeg
# Processing: ./dataset/shahbaz_sharif\10121.jpeg
# Processing: ./dataset/shahbaz_sharif\10122.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10122.jpeg
# Processing: ./dataset/shahbaz_sharif\10124.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10124.jpeg
# Processing: ./dataset/shahbaz_sharif\10126.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10126.jpeg
# Processing: ./dataset/shahbaz_sharif\10127.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10127.jpeg
# Processing: ./dataset/shahbaz_sharif\10129.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10129.jpeg
# Processing: ./dataset/shahbaz_sharif\10131.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10131.jpeg
# Processing: ./dataset/shahbaz_sharif\10133.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10133.jpeg
# Processing: ./dataset/shahbaz_sharif\10135.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10135.jpeg
# Processing: ./dataset/shahbaz_sharif\10136.jpeg
# Processing: ./dataset/shahbaz_sharif\10138.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10138.jpeg
# Processing: ./dataset/shahbaz_sharif\10140.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10140.jpeg
# Processing: ./dataset/shahbaz_sharif\10142.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10142.jpeg
# Processing: ./dataset/shahbaz_sharif\10145.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10145.jpeg
# Processing: ./dataset/shahbaz_sharif\10146.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10146.jpeg
# Processing: ./dataset/shahbaz_sharif\10148.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10148.jpeg
# Processing: ./dataset/shahbaz_sharif\10150.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10150.jpeg
# Processing: ./dataset/shahbaz_sharif\10152.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10152.jpeg
# Processing: ./dataset/shahbaz_sharif\10153.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10153.jpeg
# Processing: ./dataset/shahbaz_sharif\10154.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10154.jpeg
# Processing: ./dataset/shahbaz_sharif\10155.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10155.jpeg
# Processing: ./dataset/shahbaz_sharif\10156.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10156.jpeg
# Processing: ./dataset/shahbaz_sharif\10157.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10157.jpeg
# Processing: ./dataset/shahbaz_sharif\10158.jpeg
# Processing: ./dataset/shahbaz_sharif\10160.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10160.jpeg
# Processing: ./dataset/shahbaz_sharif\10162.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10162.jpeg
# Processing: ./dataset/shahbaz_sharif\10164.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10164.jpeg
# Processing: ./dataset/shahbaz_sharif\10165.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10165.jpeg
# Processing: ./dataset/shahbaz_sharif\10166.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10166.jpeg
# Processing: ./dataset/shahbaz_sharif\10168.jpeg
# Processing: ./dataset/shahbaz_sharif\10170.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10170.jpeg
# Processing: ./dataset/shahbaz_sharif\10173.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10173.jpeg
# Processing: ./dataset/shahbaz_sharif\10179.jpeg
# Processing: ./dataset/shahbaz_sharif\10180.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10180.jpeg
# Processing: ./dataset/shahbaz_sharif\10182.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10182.jpeg
# Processing: ./dataset/shahbaz_sharif\10183.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10183.jpeg
# Processing: ./dataset/shahbaz_sharif\10186.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10186.jpeg
# Processing: ./dataset/shahbaz_sharif\10187.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10187.jpeg
# Processing: ./dataset/shahbaz_sharif\10189.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10189.jpeg
# Processing: ./dataset/shahbaz_sharif\10191.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10191.jpeg
# Processing: ./dataset/shahbaz_sharif\10193.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10193.jpeg
# Processing: ./dataset/shahbaz_sharif\10195.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10195.jpeg
# Processing: ./dataset/shahbaz_sharif\10197.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10197.jpeg
# Processing: ./dataset/shahbaz_sharif\10198.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10198.jpeg
# Processing: ./dataset/shahbaz_sharif\10200.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10200.jpeg
# Processing: ./dataset/shahbaz_sharif\10201.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10201.jpeg
# Processing: ./dataset/shahbaz_sharif\10202.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10202.jpeg
# Processing: ./dataset/shahbaz_sharif\10203.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10203.jpeg
# Processing: ./dataset/shahbaz_sharif\10204.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10204.jpeg
# Processing: ./dataset/shahbaz_sharif\10206.jpeg
# Processing: ./dataset/shahbaz_sharif\10207.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10207.jpeg
# Processing: ./dataset/shahbaz_sharif\10208.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10208.jpeg
# Processing: ./dataset/shahbaz_sharif\10209.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10209.jpeg
# Processing: ./dataset/shahbaz_sharif\10211.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10211.jpeg
# Processing: ./dataset/shahbaz_sharif\10212.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10212.jpeg
# Processing: ./dataset/shahbaz_sharif\10213.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10213.jpeg
# Processing: ./dataset/shahbaz_sharif\10214.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10214.jpeg
# Processing: ./dataset/shahbaz_sharif\10215.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10215.jpeg
# Processing: ./dataset/shahbaz_sharif\10216.jpeg
# Processing: ./dataset/shahbaz_sharif\10220.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10220.jpeg
# Processing: ./dataset/shahbaz_sharif\10221.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10221.jpeg
# Processing: ./dataset/shahbaz_sharif\10223.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10223.jpeg
# Processing: ./dataset/shahbaz_sharif\10225.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10225.jpeg
# Processing: ./dataset/shahbaz_sharif\10228.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10228.jpeg
# Processing: ./dataset/shahbaz_sharif\10230.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10230.jpeg
# Processing: ./dataset/shahbaz_sharif\10234.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10234.jpeg
# Processing: ./dataset/shahbaz_sharif\10236.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10236.jpeg
# Processing: ./dataset/shahbaz_sharif\10237.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10237.jpeg
# Processing: ./dataset/shahbaz_sharif\10240.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10240.jpeg
# Processing: ./dataset/shahbaz_sharif\10242.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10242.jpeg
# Processing: ./dataset/shahbaz_sharif\10243.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10243.jpeg
# Processing: ./dataset/shahbaz_sharif\10245.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10245.jpeg
# Processing: ./dataset/shahbaz_sharif\10247.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10247.jpeg
# Processing: ./dataset/shahbaz_sharif\10249.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10249.jpeg
# Processing: ./dataset/shahbaz_sharif\10253.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10253.jpeg
# Processing: ./dataset/shahbaz_sharif\10254.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10254.jpeg
# Processing: ./dataset/shahbaz_sharif\10255.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10255.jpeg
# Processing: ./dataset/shahbaz_sharif\10258.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10258.jpeg
# Processing: ./dataset/shahbaz_sharif\10261.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10261.jpeg
# Processing: ./dataset/shahbaz_sharif\10263.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10263.jpeg
# Processing: ./dataset/shahbaz_sharif\10265.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10265.jpeg
# Processing: ./dataset/shahbaz_sharif\10269.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10269.jpeg
# Processing: ./dataset/shahbaz_sharif\10270.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10270.jpeg
# Processing: ./dataset/shahbaz_sharif\10271.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10271.jpeg
# Processing: ./dataset/shahbaz_sharif\10272.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10272.jpeg
# Processing: ./dataset/shahbaz_sharif\10274.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10274.jpeg
# Processing: ./dataset/shahbaz_sharif\10275.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10275.jpeg
# Processing: ./dataset/shahbaz_sharif\10276.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10276.jpeg
# Processing: ./dataset/shahbaz_sharif\10277.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10277.jpeg
# Processing: ./dataset/shahbaz_sharif\10279.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10279.jpeg
# Processing: ./dataset/shahbaz_sharif\10281.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10281.jpeg
# Processing: ./dataset/shahbaz_sharif\10282.jpg
# Processing: ./dataset/shahbaz_sharif\10283.jpg
# Processing: ./dataset/shahbaz_sharif\10284.jpg
# Processing: ./dataset/shahbaz_sharif\10285.jpg
# Processing: ./dataset/shahbaz_sharif\10286.jpg
# Processing: ./dataset/shahbaz_sharif\10287.jpg
# Processing: ./dataset/shahbaz_sharif\10288.jpeg
# Processing: ./dataset/shahbaz_sharif\10289.jpg
# Processing: ./dataset/shahbaz_sharif\10290.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10290.jpg
# Processing: ./dataset/shahbaz_sharif\10291.jpg
# Processing: ./dataset/shahbaz_sharif\10292.png
# Processing: ./dataset/shahbaz_sharif\10293.jpeg
# Processing: ./dataset/shahbaz_sharif\10294.png
# Processing: ./dataset/shahbaz_sharif\10295.jpg
# Processing: ./dataset/shahbaz_sharif\10296.jpg
# Processing: ./dataset/shahbaz_sharif\10298.png
# Skipping invalid image: ./dataset/shahbaz_sharif\10298.png
# Processing: ./dataset/shahbaz_sharif\10300.jpg
# Processing: ./dataset/shahbaz_sharif\10301.jpg
# Processing: ./dataset/shahbaz_sharif\10302.jpg
# Processing: ./dataset/shahbaz_sharif\10303.png
# Skipping invalid image: ./dataset/shahbaz_sharif\10303.png
# Processing: ./dataset/shahbaz_sharif\10304.jpg
# Processing: ./dataset/shahbaz_sharif\10305.jpg
# Processing: ./dataset/shahbaz_sharif\10306.jpeg
# Processing: ./dataset/shahbaz_sharif\10307.png
# Processing: ./dataset/shahbaz_sharif\10308.jpg
# Processing: ./dataset/shahbaz_sharif\10309.jpg
# Processing: ./dataset/shahbaz_sharif\10310.jpg
# Processing: ./dataset/shahbaz_sharif\10311.jpg
# Processing: ./dataset/shahbaz_sharif\10312.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10312.jpg
# Processing: ./dataset/shahbaz_sharif\10313.png
# Processing: ./dataset/shahbaz_sharif\10314.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10314.jpg
# Processing: ./dataset/shahbaz_sharif\10315.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10315.jpg
# Processing: ./dataset/shahbaz_sharif\10317.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10317.jpg
# Processing: ./dataset/shahbaz_sharif\10318.jpg
# Processing: ./dataset/shahbaz_sharif\10319.jpg
# Processing: ./dataset/shahbaz_sharif\10320.jpg
# Skipping invalid image: ./dataset/shahbaz_sharif\10320.jpg
# Processing: ./dataset/shahbaz_sharif\10322.jpg
# Processing: ./dataset/shahbaz_sharif\10323.jpg
# Processing: ./dataset/shahbaz_sharif\10325.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10325.jpeg
# Processing: ./dataset/shahbaz_sharif\10326.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10326.jpeg
# Processing: ./dataset/shahbaz_sharif\10327.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10327.jpeg
# Processing: ./dataset/shahbaz_sharif\10328.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10328.jpeg
# Processing: ./dataset/shahbaz_sharif\10329.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10329.jpeg
# Processing: ./dataset/shahbaz_sharif\10330.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10330.jpeg
# Processing: ./dataset/shahbaz_sharif\10332.jpeg
# Skipping invalid image: ./dataset/shahbaz_sharif\10332.jpeg

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'asif_ali_zardari': ['./dataset/cropped/asif_ali_zardari\\asif_ali_zardari1 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari1.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari10 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari10.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari12.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari14 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari14.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari15 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari15.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari16 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari16.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari2 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari2.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari3 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari3.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari4 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari4.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari6 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari6.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari7 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari7.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari8 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari8.png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari9 (2).png',
#   './dataset/cropped/asif_ali_zardari\\asif_ali_zardari9.png',
#   './dataset/cropped/asif_ali_zardari\\general_asim_munir3.png',
#   './dataset/cropped/asif_ali_zardari\\general_asim_munir4 (2).png',
#   './dataset/cropped/asif_ali_zardari\\general_asim_munir4.png'],
#  'general_asim_munir': ['./dataset/cropped/general_asim_munir\\general_asim_munir10.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir11.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir12.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir13.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir14.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir15.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir16.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir17.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir18.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir19.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir20.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir22.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir23.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir25.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir26.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir27.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir28.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir29.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir31.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir32.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir33.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir34.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir36.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir37.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir5.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir6.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir7.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir8.png',
#   './dataset/cropped/general_asim_munir\\general_asim_munir9.png'],
#  'imran_khan': ['./dataset/cropped/imran_khan\\imran_khan1.png',
#   './dataset/cropped/imran_khan\\imran_khan11.png',
#   './dataset/cropped/imran_khan\\imran_khan12.png',
#   './dataset/cropped/imran_khan\\imran_khan13.png',
#   './dataset/cropped/imran_khan\\imran_khan14.png',
#   './dataset/cropped/imran_khan\\imran_khan15.png',
#   './dataset/cropped/imran_khan\\imran_khan16.png',
#   './dataset/cropped/imran_khan\\imran_khan17.png',
#   './dataset/cropped/imran_khan\\imran_khan18.png',
#   './dataset/cropped/imran_khan\\imran_khan19.png',
#   './dataset/cropped/imran_khan\\imran_khan2.png',
#   './dataset/cropped/imran_khan\\imran_khan20.png',
#   './dataset/cropped/imran_khan\\imran_khan21.png',
#   './dataset/cropped/imran_khan\\imran_khan22.png',
#   './dataset/cropped/imran_khan\\imran_khan23.png',
#   './dataset/cropped/imran_khan\\imran_khan24.png',
#   './dataset/cropped/imran_khan\\imran_khan25.png',
#   './dataset/cropped/imran_khan\\imran_khan26.png',
#   './dataset/cropped/imran_khan\\imran_khan27.png',
#   './dataset/cropped/imran_khan\\imran_khan28.png',
#   './dataset/cropped/imran_khan\\imran_khan29.png',
#   './dataset/cropped/imran_khan\\imran_khan3.png',
#   './dataset/cropped/imran_khan\\imran_khan30.png',
#   './dataset/cropped/imran_khan\\imran_khan31.png',
#   './dataset/cropped/imran_khan\\imran_khan32.png',
#   './dataset/cropped/imran_khan\\imran_khan33.png',
#   './dataset/cropped/imran_khan\\imran_khan34.png',
#   './dataset/cropped/imran_khan\\imran_khan35.png',
#   './dataset/cropped/imran_khan\\imran_khan37.png',
#   './dataset/cropped/imran_khan\\imran_khan38.png',
#   './dataset/cropped/imran_khan\\imran_khan39.png',
#   './dataset/cropped/imran_khan\\imran_khan4.png',
#   './dataset/cropped/imran_khan\\imran_khan40.png',
#   './dataset/cropped/imran_khan\\imran_khan41.png',
#   './dataset/cropped/imran_khan\\imran_khan42.png',
#   './dataset/cropped/imran_khan\\imran_khan43.png',
#   './dataset/cropped/imran_khan\\imran_khan44.png',
#   './dataset/cropped/imran_khan\\imran_khan45.png',
#   './dataset/cropped/imran_khan\\imran_khan46.png',
#   './dataset/cropped/imran_khan\\imran_khan47.png',
#   './dataset/cropped/imran_khan\\imran_khan48.png',
#   './dataset/cropped/imran_khan\\imran_khan49.png',
#   './dataset/cropped/imran_khan\\imran_khan5.png',
#   './dataset/cropped/imran_khan\\imran_khan50.png',
#   './dataset/cropped/imran_khan\\imran_khan51.png',
#   './dataset/cropped/imran_khan\\imran_khan54.png',
#   './dataset/cropped/imran_khan\\imran_khan55.png',
#   './dataset/cropped/imran_khan\\imran_khan56.png',
#   './dataset/cropped/imran_khan\\imran_khan57.png',
#   './dataset/cropped/imran_khan\\imran_khan58.png',
#   './dataset/cropped/imran_khan\\imran_khan59.png',
#   './dataset/cropped/imran_khan\\imran_khan6.png',
#   './dataset/cropped/imran_khan\\imran_khan60.png',
#   './dataset/cropped/imran_khan\\imran_khan61.png',
#   './dataset/cropped/imran_khan\\imran_khan62.png',
#   './dataset/cropped/imran_khan\\imran_khan63.png',
#   './dataset/cropped/imran_khan\\imran_khan64.png',
#   './dataset/cropped/imran_khan\\imran_khan65.png',
#   './dataset/cropped/imran_khan\\imran_khan66.png',
#   './dataset/cropped/imran_khan\\imran_khan68.png',
#   './dataset/cropped/imran_khan\\imran_khan69.png',
#   './dataset/cropped/imran_khan\\imran_khan7.png',
#   './dataset/cropped/imran_khan\\imran_khan70.png',
#   './dataset/cropped/imran_khan\\imran_khan71.png',
#   './dataset/cropped/imran_khan\\imran_khan8.png',
#   './dataset/cropped/imran_khan\\imran_khan9.png'],
#  'nawaz_sharif': ['./dataset/cropped/nawaz_sharif\\nawaz_sharif1.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif11.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif12.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif13.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif14.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif15.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif16.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif17.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif18.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif19.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif2.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif20.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif21.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif22.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif23.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif24.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif25.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif26.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif27.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif28.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif29.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif3.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif30.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif31.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif33.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif34.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif35.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif4.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif5.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif6.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif7.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif8.png',
#   './dataset/cropped/nawaz_sharif\\nawaz_sharif9.png'],
#  'shahbaz_sharif': ['./dataset/cropped/shahbaz_sharif\\shahbaz_sharif1.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif10.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif11.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif13.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif14.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif15.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif16.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif17.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif18.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif19.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif2.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif20.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif21.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif24.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif25.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif26.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif27.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif28.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif29.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif3.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif30.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif31.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif32.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif33.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif34.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif35.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif37.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif38.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif39.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif4.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif40.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif41.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif43.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif44.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif45.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif46.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif47.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif49.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif5.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif50.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif6.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif7.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif8.png',
#   './dataset/cropped/shahbaz_sharif\\shahbaz_sharif9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'asif_ali_zardari': 0,
#  'general_asim_munir': 1,
#  'imran_khan': 2,
#  'nawaz_sharif': 3,
#  'shahbaz_sharif': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[173],
#        [198],
#        [214],
#        ...,
#        [241],
#        [ 96],
#        [ 60]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (200, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model
#
# ##### We will use SVM with rbf kernel tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.82

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.56      0.71         9
#            1       1.00      1.00      1.00         5
#            2       0.79      1.00      0.88        15
#            3       1.00      0.64      0.78        11
#            4       0.64      0.90      0.75        10
#
#     accuracy                           0.82        50
#    macro avg       0.89      0.82      0.82        50
# weighted avg       0.87      0.82      0.81        50

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.826667
# 1        random_forest    0.606667
# 2  logistic_regression    0.826667
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, multi_class='auto',
#                                      solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.88

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.82

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 6,  0,  0,  0,  3],
#        [ 0,  5,  0,  0,  0],
#        [ 0,  0, 15,  0,  0],
#        [ 0,  0,  1,  8,  2],
#        [ 0,  0,  0,  0, 10]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()

# %%
class_dict
# Out:
# {'asif_ali_zardari': 0,
#  'general_asim_munir': 1,
#  'imran_khan': 2,
#  'nawaz_sharif': 3,
#  'shahbaz_sharif': 4}

# %% [markdown]
# ## Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\lenovo\anaconda3\lib\site-packages (1.4.2)
# ['saved_model.pkl']

# %% [markdown]
# ## Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
